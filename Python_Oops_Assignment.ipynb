# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# - Object oriented programming is a computer paradigm which holds properties and methods inside the class and which use the methods to manipulate the properties of the class

# %% [markdown]
# 2. What is a class in OOP?
#
# - A class is a blueprint or template for creating objects. It defines the common attributes and methods that all objects of that type will have.
# - It is denoted by the keyword class.
# - class Student: It denotes the class whose name is "Student"

# %% [markdown]
# 3. What is an object in OOP?
# - Object is an instance of the class which has its own unique state
# - All the Object share the common behaviour

# %% [markdown]
# 4. What is the difference between abstraction and encapsulation?
# - Encapsulation is about hiding data. It's the practice of bundling an object's data and methods together and restricting direct access to its internal state
#
# - Abstraction is about hiding complexity. It involves showing only the essential features of an object to the outside world, while hiding the complex, internal implementation details

# %% [markdown]
# 5. What are dunder methods in Python?
# - Dunder methods are special methods with names that start and end with double underscores which allow a class to hook into and customize built-in Python behaviors
# - ex- __init__ , __str__ , __repr__ along with double underscore in the beginning and end.

# %% [markdown]
# 6. Explain the concept of inheritance in OOP.
# - Inheritance is a mechanism where a child class  "inherits" all the attributes and methods from an existing class (the parent class) thus promoting code reusability. For example, a Dog class and a Cat class could both inherit from a parent Animal class.

# %% [markdown]
# 7. What is polymorphism in OOP?
# - Polymorphism is the ability of an object to take on many forms.It means that a single method name can be used by different classes to produce different results or have different implementation.

# %% [markdown]
# 8. How is encapsulation achieved in Python?
# - Encapsulation is achieved in python with the help of access specifiers with the help of which we can define the access of variables which is of 3 types public(default),protected and private
# - Single Underscore (_variable): A "protected" attribute.
# - Double Underscore (__variable): A "private" attribute.

# %% [markdown]
# 9. What is a constructor in Python?
# - constructor is a special function or dunder method which automatically gets called when an object of a class is initialised thus especially used for initialising the object or instance of a class.
# - It is written with the help of __init__ keyword

# %% [markdown]
# 10. What are class and static methods in Python?
# - Class Method (@classmethod): This method is bound to the class itself, not the instance. It receives the class (cls) as its first argument instead of self. It's often used for "factory methods" that create new instances of the class in a specific way. It is basically used as an alternative to the constructor of a class.
# - Static Method (@staticmethod): This method is just a regular function that lives inside the class's namespace. It doesn't receive self or cls as an argument. It's used for utility functions that are logically related to the class but don't need to access any instance or class state.

# %% [markdown]
# 11. What is method overloading in Python?
# - Python does not support method overloading. In Python, if we define a method with the same name twice, the second definition simply overwrites the first.
#
# - we can simulate overloading by using default arguments or variable-length arguments (*args, **kwargs).

# %% [markdown]
# 12. What is method overriding in OOP?
# - Method Overriding is a concept in which the parent class function gets implemented or overriden by the child class with some other functionality with the function name being same in both child and parent class.

# %% [markdown]
# 13. What is a property decorator in Python?
# - Property decorator is a type of decorator which allows methods to be declared as property thus allowing the method to be called without parenthesis.
# - these are basically used to create getters and setters to control the attribute values.
# - To declare the method as property we have to use the keyword @property

# %% [markdown]
# 14. Why is polymorphism important in OOP?
# - Polymorphism is crucial because it promotes flexibility and decoupling. It allows us to write code that can operate on a general category of objects and have it automatically work with any new types we create later.

# %% [markdown]
# 15. What is an abstract class in Python?
# - Abstract classes are the ones which cannot be instantiated and thus all the methods do not have any implementation.
# - It acts as a base class for all the other classes in which the child classes implement the functionality of the base class.

# %% [markdown]
# 16. What are the advantages of OOP?
# - Provides a Modular method to write code
# - Provide Reusable set of code
# - Its easier to maintain and find bugs
# - polymorphism makes the code more flexible
# - Abstraction concept is used which hides the internal implementation of the complex systems

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?
# - class variables are the one which are shared by all the instances of the class and are declared outside the class method but inside the class.
# - instance variables are the ones which are unique to the instances of the class and are not shared and thus are created new for each of the object declared.they are initialised inside the init constructor function.

# %% [markdown]
# 18. What is multiple inheritance in Python?
# - Multiple inheritance is a type of inheritance in which the a class inherits properties of multiple parent class.
# - it give rise to the diamond problem which is resolved by the Method Resoultion Order.

# %% [markdown]
# 19. Explain the purpose of __str__ and __repr__ methods in Python.
# - Both methods provide a string representation of an object, but for different usecases:
#
# - __str__ : Should return a string that is easy for an end-user to read. This is what print() and str() use.
#
# - __repr__ : Should return an "unambiguous" string representation of the object, intended for developers. Ideally, it should be a valid Python expression that could be used to recreate the object. If __str__ isn't defined, __repr__ is used as a fallback.

# %% [markdown]
# 20. What is the significance of the super() function in Python?
# - The super() function is used in subclasses to call methods that are defined in their superclass (parent). Its most common use is inside the __init__ method to ensure that the parent's __init__ is also called, allowing the parent class to initialize its own attributes.

# %% [markdown]
# 21. What is the significance of the __del__ method in Python?
# - del method is the destructor function which acts like a garbage collector that gets executed before the object of a class gets destroyed.
# - Its main work is to deallocate the resources allocated to the object.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
# - @classmethod: Receives the class (cls) as its first argument. It can access or modify class-level variables (class state).
#
# - @staticmethod: Receives no special first argument (no self or cls). It's just a normal function namespaced inside the class and cannot access or modify class or instance state. It's a utility function.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
# - A parent class defines a standard method
# - Multiple child classes inherit from this parent and provide their own specific implementation
# - You can then write a function that accepts a list of  objects and calls a method on each one. Python will automatically execute the correct version of method for each object,

# %% [markdown]
# 24. What is method chaining in Python OOP?
# - Method chaining is a style where you call multiple methods on the same object in a single, continuous line of code
# - his is achieved by having each method in the chain except the last one.

# %% [markdown]
# 25. What is the purpose of the __call__ method in Python?
# - most common use case. It allows an object to behave like a function, but unlike a simple function, the object can maintain its own internal state between calls.
# - we can use a class to decorate another function or, another class.
#
# - __init__: This method runs once when the decorator is first applied. It receives the function/class being decorated and stores it.
#
# - __call__: This method runs every time the decorated function/class is called or instantiated. It's where you add your decorator's logic.

# %% [markdown]
# # Practical Questions

# %% [markdown]
#  1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
# that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("A generic animal sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

my_dog = Dog()
my_dog.speak()
# Out:
# Bark!

# %% [markdown]
# 2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
# from it and implement the area() method in both.

# %%
from abc import ABC,abstractmethod
import math
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

class Rectangle(Shape):
  def __init__(self,width,height):
    self.width=width
    self.height=height

  def area(self):
        return self.width * self.height

c = Circle(5)
r = Rectangle(10, 4)
print(f"Circle Area: {c.area()}")
print(f"Rectangle Area: {r.area()}")
# Out:
# Circle Area: 78.53981633974483
# Rectangle Area: 40

# %% [markdown]
# 3. . Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
# and further derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
  def __init__(self):
    self.type="Vehicle"

class Car(Vehicle):
  def __init__(self):
    super().__init__()
    self.type="Car"

class ElectricCar(Car):
  def __init__(self,battery_size):
   super().__init__()
   self.battery_size = battery_size

my_tesla = ElectricCar("100kWh")
print(f"Type: {my_tesla.type}")
print(f"Battery: {my_tesla.battery_size}")
# Out:
# Type: Car
# Battery: 100kWh

# %% [markdown]
# 4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
# Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow is flying high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly, but waddles")

def make_bird_fly(bird):
    bird.fly()

sparrow = Sparrow()
penguin = Penguin()

make_bird_fly(sparrow)
make_bird_fly(penguin)
# Out:
# Sparrow is flying high
# Penguin cannot fly, but waddles

# %% [markdown]
# 5.  Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
# balance and methods to deposit, withdraw, and check balance

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}")
        else:
            print("Deposit amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew ${amount}. New balance: ${self.__balance}")
        else:
            print("Insufficient funds.")

    def check_balance(self):
        print(f"Current balance is: ${self.__balance}")

my_account = BankAccount(100)
my_account.check_balance()
my_account.deposit(50)
my_account.withdraw(70)
my_account.withdraw(200)
# Out:
# Current balance is: $100
# Deposited $50
# Withdrew $70. New balance: $80
# Insufficient funds.

# %% [markdown]
# 6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
# and Piano that implement their own version of play().

# %%
class Instrument:
    def play(self):
        print("Playing a generic instrument sound")

class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar")

class Piano(Instrument):
    def play(self):
        print("Playing the piano keys")

def play_music(instruments):
    for instrument in instruments:
        instrument.play()

guitar = Guitar()
piano = Piano()
band = [guitar, piano]
play_music(band)
# Out:
# Strumming the guitar
# Playing the piano keys

# %% [markdown]
# 7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static
# method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
  @classmethod
  def add_numbers(cls,a,b):
      print("Belonging to:",cls.__name__)
      return a+b

  @staticmethod
  def subtract_numbers(a, b):
        return a - b

print(f"Addition: {MathOperations.add_numbers(5, 10)}")
print(f"Subtraction: {MathOperations.subtract_numbers(10, 5)}")
# Out:
# Belonging to: MathOperations
# Addition: 15
# Subtraction: 5

# %% [markdown]
# 8.  Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    total_persons = 0

    def __init__(self, name):
        self.name = name
        Person.total_persons += 1

    @classmethod
    def get_total_persons(cls):
        return cls.total_persons

p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")
print(f"Total persons created: {Person.get_total_persons()}")
# Out:
# Total persons created: 3

# %% [markdown]
# 9.  Write a class Fraction with attributes numerator and denominator. Override the str method to display the
# fraction as "numerator/denominator".

# %%
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

print(Fraction(3,4))
# Out:
# 3/4

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
# vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
            new_x = self.x + other.x
            new_y = self.y + other.y
            return Vector(new_x, new_y)

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

v1 = Vector(2, 3)
v2 = Vector(5, 1)
v3 = v1 + v2
print(v3)
# Out:
# Vector(7, 4)

# %% [markdown]
# 11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
# {name} and I am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Aditya", 22)
p.greet()
# Out:
# Hello, my name is Aditya and I am 22 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute
# the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        if not self.grades:
            return 0
        return sum(self.grades) / len(self.grades)

s1 = Student("Ayush", [80, 90, 88, 92])
print(f"Ayush's average grade: {s1.average_grade()}")
# Out:
# Ayush's average grade: 87.5

# %% [markdown]
# 13.  Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
# area.

# %%
class Rectangle:
    def __init__(self):
        self.width = 0
        self.height = 0

    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

r = Rectangle()
r.set_dimensions(10, 5)
print(f"Rectangle area: {r.area()}")
# Out:
# Rectangle area: 50

# %% [markdown]
# 14.  Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
# and hourly rate. Create a derived class Manager that adds a bonus to the salary.

# %%
class Employee:
    def __init__(self, worked, rate):
        self.worked = worked
        self.rate = rate

    def calculate_salary(self):
        return self.worked * self.rate

class Manager(Employee):
    def __init__(self, worked, rate, bonus):
        super().__init__(worked,rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

emp = Employee(40, 25)
mgr = Manager(40, 50, 1000)
print(f"Employee salary: ${emp.calculate_salary()}")
print(f"Manager salary: ${mgr.calculate_salary()}")
# Out:
# Employee salary: $1000
# Manager salary: $3000

# %% [markdown]
# 15.  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
# calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

apple = Product("Apple", 0.5, 100)
print(f"Total price for {apple.name}s: ${apple.total_price()}")
# Out:
# Total price for Apples: $50.0

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
# implement the sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

c = Cow()
s = Sheep()
c.sound()
s.sound()
# Out:
# Moo
# Baa

# %% [markdown]
# 17.  Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
# returns a formatted string with the book's details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year: {self.year_published}"

book1 = Book("Book1", "George", 2000)
print(book1.get_book_info())
# Out:
# Title: Book1, Author: George, Year: 2000

# %% [markdown]
# 18. Create a class House with attributes address and price. Create a derived class Mansion that adds an
# attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, nor):
        super().__init__(address, price)
        self.nor = nor

my_mansion = Mansion("123 Lane", 5000000, 20)
print(f"Address: {my_mansion.address}")
print(f"Price: ${my_mansion.price}")
print(f"Rooms: {my_mansion.nor}")
# Out:
# Address: 123 Lane
# Price: $5000000
# Rooms: 20
